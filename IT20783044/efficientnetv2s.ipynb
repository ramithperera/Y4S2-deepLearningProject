# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install the 'timm' library for working with pre-trained models and 'faiss-gpu' for GPU-accelerated similarity search.

# !pip install timm faiss-gpu
# Out:
# Collecting timm
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 15.9 MB/s eta 0:00:00
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.4 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (17.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, faiss-gpu, huggingface-hub, timm
# Successfully installed faiss-gpu-1.7.2 huggingface-hub-0.17.3 safetensors-0.3.3 timm-0.9.7

# %%
# Standard Libraries
import time
import os
import copy

# NumPy and Pandas
import numpy as np
import pandas as pd

# PyTorch and related modules
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader

# torchvision for image-related operations
from torchvision import transforms, datasets
import torchvision

import matplotlib.pyplot as plt

# timm for working with pre-trained models
import timm

# %%
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("timm version:", timm.__version__)
print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# NumPy version: 1.23.5
# Pandas version: 1.5.3
# timm version: 0.9.7
# PyTorch version: 2.0.1+cu118
# torchvision version: 0.15.2+cu118

# %%
# !unzip '/content/drive/MyDrive/DL Labs/dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_099.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_100.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_101 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_101.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_102 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_102.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_103 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_103.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_104 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_104 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_104.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_105 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_105 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_105 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_105.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_106 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_106 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_106 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_106 (5).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_106.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_107 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_107 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_107 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_107.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_110.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_111 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_111 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_111.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_112 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_112.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_113.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_114 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_114.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_115 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_115.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_116 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_116 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_116 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_116.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_117 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_117 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_117.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_118 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_118 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_118 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_118.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_119 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_119.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_120 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_120.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_121.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_122 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_122.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_123 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_123 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_123.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_124 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_124.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_125 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_125.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_126 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_126 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_126.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_127 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_127.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_128 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_128 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_128 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_128.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_129 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_129.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_130 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_130 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_130.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_131 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_131 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_131 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_131.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_132.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_133 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_133.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_134 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_134 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_134.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_135 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_135.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_136 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_136 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_136 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_136.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_137.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_138 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_138.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_139 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_139.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_140.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_141 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_141.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_142 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_142.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_144 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_144.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_145 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_145.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_146 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_146.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_147 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_147.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_148 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_148.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_150 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_150 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_150.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_151 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_151 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_151 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_151.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_152 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_152 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_152 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_152.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_153 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_153 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_153 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_153 (5).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_153.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_154 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_154 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_154.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_155 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_155 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_155.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_156 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_156.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_157 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_157 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_157.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_158.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_159 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_159.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_160 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_160 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_160.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_161 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_161.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_162 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_162 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_162.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_163 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_163.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_164 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_164.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_165 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_165.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_166 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_166.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_167 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_167.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_168 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_168 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_168 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_168.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_169.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_170 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_170.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_171 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_171 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_171.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_173 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_173 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_173.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_174.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_175 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_175 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_175.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_176 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_176 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_176.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_177 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_177 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_177.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_178 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_178 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_178.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_179 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_179.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_180 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_180.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_181 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_181.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_182 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_182 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_182 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_182.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_183.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_184.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_185 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_185.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_186 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_186 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_186.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_187 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_187 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_187.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_188.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_189 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_189 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_189.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_190.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_191 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_191 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_191 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_191.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_192 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_192 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_192.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_194.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_195.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_196 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_196 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_196.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_197 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_197.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_198 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_198 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_198 (4).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images_198.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/running/images
(2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_377 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_377.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_378 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_378 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_378.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_379 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_379 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_379.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_380 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_380.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_381 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_381 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_381.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_382 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_382.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_383 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_383.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_384 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_384.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_385 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_385 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_385.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_386 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_386 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_386.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_387 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_387 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_387.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_388 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_388.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_389 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_389 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_389.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_390 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_390 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_390.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_391 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_391.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_392 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_392 (3).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_392.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_393 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_393.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_394 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_394.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_395.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_396.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_397 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_397.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_398.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_399 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_399.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_400 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_400.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_401 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_401.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_402 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_402.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_403.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_404 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_404.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_405 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_405.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_406 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_406.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_407 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_407.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_408 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_408.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_409 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_409.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_410 (2).jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_410.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_411.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_412.jpg
#   inflating: emirhan_human_dataset/datasets/human_data/train_data/using_laptop/images_413.jpg
#   inflating: human_action_detection_with_artificial_intelligence.py

# %%
transformations = {
    'train': transforms.Compose([
        # Randomly resize and crop the image to 224x224 pixels
        transforms.RandomResizedCrop(224),
        # Randomly flip the image horizontally for data augmentation
        transforms.RandomHorizontalFlip(),
        # Convert the image to a PyTorch tensor
        transforms.ToTensor(),
        # Normalize the image with mean and standard deviation values
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_directory = '../content/emirhan_human_dataset/datasets/human_data/'

datasets = {
    'train': datasets.ImageFolder(os.path.join(data_directory, 'train_data'), transformations['train']),
    'test': datasets.ImageFolder(os.path.join(data_directory, 'test_data'), transformations['test'])
}

# %%
dataloaders = {
    'train': torch.utils.data.DataLoader(datasets['train'], batch_size=4, shuffle=True, num_workers=4),
    'test': torch.utils.data.DataLoader(datasets['test'], batch_size=4, shuffle=True, num_workers=4)
}

dataset_sizes = {
    'train': len(datasets['train']),
    'test': len(datasets['test'])
}

class_names = datasets['train'].classes
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def train_model(model, loss_fn, optimizer, scheduler, num_epochs=25):
    start_time = time.time()
    best_model_weights = copy.deepcopy(model.state_dict())
    best_accuracy = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)
        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train() # Set model to training mode
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for batch_inputs, batch_labels in dataloaders[phase]:
                batch_inputs = batch_inputs.to(device)
                batch_labels = batch_labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward pass
                # Track history if only in training phase
                with torch.set_grad_enabled(phase == 'train'):
                    batch_outputs = model(batch_inputs)
                    _, batch_preds = torch.max(batch_outputs, 1)
                    batch_loss = loss_fn(batch_outputs, batch_labels)

                    # Backward pass and optimize only if in training phase
                    if phase == 'train':
                        batch_loss.backward()
                        optimizer.step()

                running_loss += batch_loss.item() * batch_inputs.size(0)
                running_corrects += torch.sum(batch_preds == batch_labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_accuracy = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_accuracy:.4f}')

            # Deep copy the model
            if phase == 'test' and epoch_accuracy > best_accuracy:
                best_accuracy = epoch_accuracy
                best_model_weights = copy.deepcopy(model.state_dict())

        print()

    elapsed_time = time.time() - start_time
    print(f'Training complete in {elapsed_time // 60:.0f}m {elapsed_time % 60:.0f}s')
    print(f'Best Validation Acc: {best_accuracy:.4f}')
    # Load best model weights
    model.load_state_dict(best_model_weights)
    return model

# %%
#create an EfficientNetV2 model and move it to the specified device:
efficientnet_model = timm.create_model("tf_efficientnetv2_s_in21ft1k", pretrained=True, drop_rate=0.3, num_classes=len(class_names))
efficientnet_model = efficientnet_model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/_factory.py:114: UserWarning: Mapping deprecated model name tf_efficientnetv2_s_in21ft1k to current tf_efficientnetv2_s.in21k_ft_in1k.
#   model = create_fn(
# Downloading model.safetensors:   0%|          | 0.00/86.5M [00:00<?, ?B/s]

# %%
loss_criterion = nn.CrossEntropyLoss() # Define the loss function (criterion)
optimizer_efficientnet = optim.SGD(efficientnet_model.parameters(), lr=0.001, momentum=0.9) # Specify the optimizer for training (Stochastic Gradient Descent - SGD)

# %%
learning_rate_scheduler = lr_scheduler.StepLR(optimizer_efficientnet, step_size=7, gamma=0.1) ## Decay the learning rate by a factor of 0.1 every 7 epochs

# %%
trained_efficientnet_model = train_model(efficientnet_model, loss_criterion, optimizer_efficientnet, learning_rate_scheduler, num_epochs=10)
# Out:
# Epoch 0/9
# ----------
# Train Loss: 1.8786 Acc: 0.4280
# Test Loss: 0.8653 Acc: 0.7350
#
# Epoch 1/9
# ----------
# Train Loss: 1.3165 Acc: 0.5909
# Test Loss: 0.7846 Acc: 0.7613
#
# Epoch 2/9
# ----------
# Train Loss: 1.1685 Acc: 0.6375
# Test Loss: 0.7604 Acc: 0.7760
#
# Epoch 3/9
# ----------
# Train Loss: 1.0733 Acc: 0.6701
# Test Loss: 0.6921 Acc: 0.7970
#
# Epoch 4/9
# ----------
# Train Loss: 0.9940 Acc: 0.6916
# Test Loss: 0.6521 Acc: 0.8090
#
# Epoch 5/9
# ----------
# Train Loss: 0.9561 Acc: 0.6999
# Test Loss: 0.6567 Acc: 0.8003
#
# Epoch 6/9
# ----------
# Train Loss: 0.9106 Acc: 0.7177
# Test Loss: 0.6289 Acc: 0.8183
#
# Epoch 7/9
# ----------
# Train Loss: 0.7919 Acc: 0.7452
# Test Loss: 0.6041 Acc: 0.8233
#
# Epoch 8/9
# ----------
# Train Loss: 0.7518 Acc: 0.7645
# Test Loss: 0.5955 Acc: 0.8250
#
# Epoch 9/9
# ----------
# Train Loss: 0.7501 Acc: 0.7611
# Test Loss: 0.5868 Acc: 0.8253
#
# Training complete in 57m 17s
# Best Validation Acc: 0.8253

# %%
correct = 0
total = 0

# Disable gradient computation for this section as we're just testing the model
with torch.no_grad():
    # Loop through the test dataset
    for inputs, labels in dataloaders['test']:
        # Move inputs and labels to the device (CPU or GPU)
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = trained_efficientnet_model(inputs) # Forward pass to get predictions from the model

        _, predicted = torch.max(outputs.data, 1) # Get the index of the predicted class (class with the highest probability)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()  # Count the number of correct predictions by comparing with the true labels


accuracy = 100 * correct / total

print(f"Accuracy on test data: {accuracy:.2f}%")
# Out:
# Accuracy on test data: 82.53%
